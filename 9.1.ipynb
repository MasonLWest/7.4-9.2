# %% [markdown]
# 9.1

# %%
"""
Project 9.1
Resources to manage a student's name and test scores.
Includes methods for comparisons and testing for equality.
"""

class Student(object):
    """Represents a student."""

    def __init__(self, name, number):
        """All scores are initially 0."""
        self.name = name
        self.scores = []
        for count in range(number):
            self.scores.append(0)

    def getName(self):
        """Returns the student's name."""
        return self.name
  
    def setScore(self, i, score):
        """Resets the ith score, counting from 1."""
        self.scores[i - 1] = score

    def getScore(self, i):
        """Returns the ith score, counting from 1."""
        return self.scores[i - 1]
   
    def getAverage(self):
        """Returns the average score."""
        return sum(self.scores) / len(self._scores)
    
    def getHighScore(self):
        """Returns the highest score."""
        return max(self.scores)
 
    def __str__(self):
        """Returns the string representation of the student."""
        return "Name: " + self.name  + "\nScores: " + \
               " ".join(map(str, self.scores))

    def __eq__(self, other):
        """Tests for equality based on the names of the students."""
        return self.name == other.name

    def __lt__(self, other):
        """Tests if the name of the current student is less than the name of the other student."""
        return self.name < other.name

    def __ge__(self, other):
        """Tests if the name of the current student is greater than or equal to the name of the other student."""
        return self.name >= other.name

def main():
    """Tests all of the comparison operators."""
    student1 = Student("Ken", 5)
    student2 = Student("John", 5)
    student3 = Student("Ken", 3)

    print(student1 == student2, ": False")
    print(student1 == student3, ": True")
    print(student1 < student2, ": True")
    print(student1 < student3, ": False")
    print(student1 >= student2, ": True")
    print(student1 >= student3, ": True")
    print(student1 > student2, ": False")
    print(student1 > student3, ": True")
    print(student1 != student2, ": True")
    print(student1 != student3, ": False")

if __name__ == "__main__":
    main()
